# %% [markdown]
# # 2. RNN

# %% [markdown]
# ### Recurrent Neural Networks
# RNN은 자기자신을 향하는 weight를 이용해 데이터간의 시간관계를 학습할 수 있다. 이러한 문제들을 시계열 학습이라고 부르며, 기존에 널리 쓰이던 Hidden Markov Model을 뉴럴넷을 이용해 구현했다고 볼 수 있다.

# %% [markdown]
# ## 필요 라이브러리

# %%
from numpy import array
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN

# %% [markdown]
# ## 데이터 예시 세팅
# x　　y<br>
# 123　4<br>
# 234　5<br>
# 345　6<br>
# 456　7<br>
# 다음 수를 예측할 수 있는 모델을 목표로 하는 데이터 세팅

# %%
x = array([[1,2,3], [2,3,4], [3,4,5], [4,5,6], [5,6,7]])
y = array([4,5,6,7,8])

print('x shape : ', x.shape) # (4,3)
print('y shape : ', y.shape) # (4,)
# Out:
# x shape :  (5, 3)
# y shape :  (5,)

# %% [markdown]
# RNN 모델에 맞게 Reshape

# %%
x = x.reshape((x.shape[0], x.shape[1], 1)) # (4,3,1) reshape 전체 곱 수 같아야 4*3=4*3*1
print('x shape : ', x.shape)
print(x)
# Out:
# x shape :  (5, 3, 1)
# [[[1]
#   [2]
#   [3]]
#
#  [[2]
#   [3]
#   [4]]
#
#  [[3]
#   [4]
#   [5]]
#
#  [[4]
#   [5]
#   [6]]
#
#  [[5]
#   [6]
#   [7]]]

# %% [markdown]
# ## 모델 구성

# %%
model = Sequential()
model.add(SimpleRNN(10, activation = 'relu', input_shape=(3,1)))
# DENSE와 사용법 동일하나 input_shape=(열, 몇개씩잘라작업)
model.add(Dense(5))
model.add(Dense(1))
 
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 10)                120
#
#  dense (Dense)               (None, 5)                 55
#
#  dense_1 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 모델 학습 시키기

# %%
model.compile(optimizer='adam', loss='mse')
model.fit(x, y, epochs=100, batch_size=1)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 3s 6ms/step - loss: 4.5021
# Epoch 2/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.4577
# Epoch 3/100
# 5/5 [==============================] - 0s 5ms/step - loss: 1.2134
# Epoch 4/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.6186
# Epoch 5/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3381
# Epoch 6/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3997
# Epoch 7/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.4888
# Epoch 8/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4704
# Epoch 9/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4197
# Epoch 10/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3245
# Epoch 11/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3314
# Epoch 12/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.3129
# Epoch 13/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3058
# Epoch 14/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2958
# Epoch 15/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2925
# Epoch 16/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2683
# Epoch 17/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.2680
# Epoch 18/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.2619
# Epoch 19/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2503
# Epoch 20/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2438
# Epoch 21/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2372
# Epoch 22/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2308
# Epoch 23/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2189
# Epoch 24/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2131
# Epoch 25/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.2110
# Epoch 26/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2079
# Epoch 27/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1995
# Epoch 28/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1856
# Epoch 29/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1801
# Epoch 30/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1750
# Epoch 31/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1686
# Epoch 32/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1639
# Epoch 33/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1603
# Epoch 34/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1505
# Epoch 35/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1436
# Epoch 36/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1412
# Epoch 37/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1406
# Epoch 38/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1308
# Epoch 39/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1276
# Epoch 40/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1234
# Epoch 41/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1193
# Epoch 42/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1168
# Epoch 43/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1127
# Epoch 44/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1098
# Epoch 45/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1075
# Epoch 46/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1042
# Epoch 47/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1030
# Epoch 48/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1005
# Epoch 49/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0941
# Epoch 50/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0894
# Epoch 51/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0902
# Epoch 52/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0867
# Epoch 53/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0832
# Epoch 54/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0806
# Epoch 55/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0822
# Epoch 56/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0763
# Epoch 57/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0733
# Epoch 58/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0710
# Epoch 59/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0740
# Epoch 60/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0708
# Epoch 61/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0712
# Epoch 62/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0661
# Epoch 63/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0603
# Epoch 64/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0614
# Epoch 65/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0569
# Epoch 66/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0560
# Epoch 67/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0558
# Epoch 68/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0533
# Epoch 69/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0554
# Epoch 70/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0518
# Epoch 71/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0479
# Epoch 72/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0495
# Epoch 73/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0447
# Epoch 74/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0420
# Epoch 75/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0400
# Epoch 76/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0406
# Epoch 77/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0377
# Epoch 78/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0364
# Epoch 79/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0366
# Epoch 80/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0344
# Epoch 81/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0339
# Epoch 82/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0302
# Epoch 83/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0287
# Epoch 84/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0289
# Epoch 85/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0293
# Epoch 86/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0280
# Epoch 87/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0258
# Epoch 88/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0276
# Epoch 89/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0235
# Epoch 90/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0226
# Epoch 91/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0224
# Epoch 92/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0211
# Epoch 93/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0222
# Epoch 94/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0214
# Epoch 95/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0179
# Epoch 96/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0177
# Epoch 97/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0178
# Epoch 98/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0160
# Epoch 99/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0181
# Epoch 100/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0150

# %% [markdown]
# ## TEST

# %%
x_input = array([6,7,8])
x_input = x_input.reshape((1,3,1))

yhat = model.predict(x_input)
print(yhat)
# Out:
# [[9.208433]]

# %% [markdown]
# 출처: https://ebbnflow.tistory.com/135 [Dev Log : 삶은 확률의 구름]
